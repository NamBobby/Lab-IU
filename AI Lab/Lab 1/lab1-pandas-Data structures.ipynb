# %%
import pandas as pd

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
try:
    import seaborn
except ImportError:
    pass

# %% [markdown]
# # Tabular data

# %%
# Here is just the sample dir, you should correct your dir
df = pd.read_csv("data/titanic.csv")

# %% [markdown]
# ## Practice 1

# %% [markdown]
# **Print out top rows in the data**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
print(df.head(n=1).to_string(index=False))
# Out:
#  PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  Parch     Ticket  Fare Cabin Embarked
#            1         0       3  Braund, Mr. Owen Harris  male  22.0      1      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# Starting from reading this dataset, to answering questions about this data in a few lines of code:

# %% [markdown]
# **What is the age distribution of the passengers?**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
column = df['Age']
max_value = column. max()
min_value = column. min()
print(min_value , ' to ' , max_value)
# Out:
# 0.42  to  80.0

# %% [markdown]
# **How does the survival rate of the passengers differ between sexes?**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
print('Rate of male survival: ',(len(df[(df.Sex == 'male') & (df.Survived == 1)]) / len(df[(df.Sex == 'male') & (df.Survived == 0)])))
print('Rate of female survival: ',(len(df[(df.Sex == 'female') & (df.Survived == 1)]) / len(df[(df.Sex == 'female') & (df.Survived == 0)])))
# Out:
# Rate of male survival:  0.2329059829059829
# Rate of female survival:  2.876543209876543

# %% [markdown]
# **Or how does it differ between the different classes?**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
print('Rate of male survival class 1 : ',(len(df[(df.Sex == 'male') & (df.Survived == 1) & (df.Pclass == 1 )]) / len(df[(df.Sex == 'male') & (df.Survived == 0) & (df.Pclass == 1) ])))
print('Rate of male survival class 2 : ',(len(df[(df.Sex == 'male') & (df.Survived == 1) & (df.Pclass == 2 )]) / len(df[(df.Sex == 'male') & (df.Survived == 0) & (df.Pclass == 2) ])))
print('Rate of male survival class 3 : ',(len(df[(df.Sex == 'male') & (df.Survived == 1) & (df.Pclass == 3 )]) / len(df[(df.Sex == 'male') & (df.Survived == 0) & (df.Pclass == 3) ])))
print('Rate of female survival class 1 : ',(len(df[(df.Sex == 'female') & (df.Survived == 1) & (df.Pclass == 1 )]) / len(df[(df.Sex == 'female') & (df.Survived == 0) & (df.Pclass == 1) ])))
print('Rate of female survival class 2 : ',(len(df[(df.Sex == 'female') & (df.Survived == 1) & (df.Pclass == 2 )]) / len(df[(df.Sex == 'female') & (df.Survived == 0) & (df.Pclass == 2) ])))
print('Rate of female survival class 3 : ',(len(df[(df.Sex == 'female') & (df.Survived == 1) & (df.Pclass == 3 )]) / len(df[(df.Sex == 'female') & (df.Survived == 0) & (df.Pclass == 3) ])))
# Out:
# Rate of male survival class 1 :  0.5844155844155844
# Rate of male survival class 2 :  0.18681318681318682
# Rate of male survival class 3 :  0.15666666666666668
# Rate of female survival class 1 :  30.333333333333332
# Rate of female survival class 2 :  11.666666666666666
# Rate of female survival class 3 :  1.0

# %% [markdown]
# **Are young people more likely to survive?**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
print('the teenage: ',len(df[(df.Age >= 0) & (df.Age <= 14) & (df.Survived == 1)]))

print('the middle-age: ', len(df[(df.Age >= 15) & (df.Age <= 64) & df.Survived == 1]))

print('the old people: ', len(df[(df.Age >= 64) & df.Survived == 1]))
# Out:
# the teenage:  45
# the middle-age:  244
# the old people:  1

# %%
45 + 244 > 1
# Out:
# True

# %% [markdown]
# All the needed functionality for the above examples will be explained throughout this tutorial.

# %% [markdown]
# # Data structures
#
# Pandas provides two fundamental data objects, for 1D (``Series``) and 2D data (``DataFrame``).

# %% [markdown]
# ## Series
#
# A Series is a basic holder for **one-dimensional labeled data**. It can be created much as a NumPy array is created:

# %%
s = pd.Series([0.1, 0.2, 0.3, 0.4])
s
# Out:
# 0    0.1
# 1    0.2
# 2    0.3
# 3    0.4
# dtype: float64

# %% [markdown]
# ### Attributes of a Series: `index` and `values`
#
# The series has a built-in concept of an **index**, which by default is the numbers *0* through *N - 1*

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# You can access the underlying numpy array representation with the `.values` attribute:

# %%
s.values
# Out:
# array([0.1, 0.2, 0.3, 0.4])

# %% [markdown]
# We can access series values via the index, just like for NumPy arrays:

# %%
s[0]
# Out:
# 0.1

# %% [markdown]
# Unlike the NumPy array, though, this index can be something other than integers:

# %%
s2 = pd.Series(np.arange(4), index=['a', 'b', 'c', 'd'])
s2
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
s2['c']
# Out:
# 2

# %% [markdown]
# In this way, a ``Series`` object can be thought of as similar to an ordered dictionary mapping one typed value to another typed value.
#
# In fact, it's possible to construct a series directly from a Python dictionary:

# %%
pop_dict = {'Germany': 81.3, 
            'Belgium': 11.3, 
            'France': 64.3, 
            'United Kingdom': 64.9, 
            'Netherlands': 16.9}
population = pd.Series(pop_dict)
population
# Out:
# Germany           81.3
# Belgium           11.3
# France            64.3
# United Kingdom    64.9
# Netherlands       16.9
# dtype: float64

# %% [markdown]
# We can index the populations like a dict as expected:

# %%
population['France']
# Out:
# 64.3

# %% [markdown]
# but with the power of numpy arrays:

# %%
population * 1000
# Out:
# Germany           81300.0
# Belgium           11300.0
# France            64300.0
# United Kingdom    64900.0
# Netherlands       16900.0
# dtype: float64

# %% [markdown]
# ## DataFrames: Multi-dimensional Data
#
# A DataFrame is a **tablular data structure** (multi-dimensional object to hold labeled data) comprised of rows and columns, akin to a spreadsheet, database table, or R's data.frame object. You can think of it as multiple Series object which share the same index.

# %% [markdown]
# One of the most common ways of creating a dataframe is from a dictionary of arrays or lists.
#
# Note that in the IPython notebook, the dataframe will display in a rich HTML view:

# %%
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries
# Out:
#           country  population    area    capital
# 0         Belgium        11.3   30510   Brussels
# 1          France        64.3  671308      Paris
# 2         Germany        81.3  357050     Berlin
# 3     Netherlands        16.9   41526  Amsterdam
# 4  United Kingdom        64.9  244820     London

# %% [markdown]
# ### Attributes of the DataFrame
#
# A DataFrame has besides a `index` attribute, also a `columns` attribute:

# %%
countries.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
countries.columns
# Out:
# Index(['country', 'population', 'area', 'capital'], dtype='object')

# %% [markdown]
# To check the data types of the different columns:

# %%
countries.dtypes
# Out:
# country        object
# population    float64
# area            int64
# capital        object
# dtype: object

# %% [markdown]
# An overview of that information can be given with the `info()` method:

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     5 non-null      object
#  1   population  5 non-null      float64
#  2   area        5 non-null      int64
#  3   capital     5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# Also a DataFrame has a `values` attribute, but attention: when you have heterogeneous data, all values will be upcasted:

# %%
countries.values
# Out:
# array([['Belgium', 11.3, 30510, 'Brussels'],
#        ['France', 64.3, 671308, 'Paris'],
#        ['Germany', 81.3, 357050, 'Berlin'],
#        ['Netherlands', 16.9, 41526, 'Amsterdam'],
#        ['United Kingdom', 64.9, 244820, 'London']], dtype=object)

# %% [markdown]
# If we don't like what the index looks like, we can reset it and set one of our columns:

# %%
countries = countries.set_index('country')
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %% [markdown]
# To access a Series representing a column in the data, use typical indexing syntax:

# %%
countries['area']
# Out:
# country
# Belgium            30510
# France            671308
# Germany           357050
# Netherlands        41526
# United Kingdom    244820
# Name: area, dtype: int64

# %% [markdown]
# # Basic operations on Series/Dataframes

# %% [markdown]
# As you play around with DataFrames, you'll notice that many operations which work on NumPy arrays will also work on dataframes.

# %%
# redefining the example objects

population = pd.Series({'Germany': 81.3, 'Belgium': 11.3, 'France': 64.3, 
                        'United Kingdom': 64.9, 'Netherlands': 16.9})

countries = pd.DataFrame({'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']})

# %% [markdown]
# ### Elementwise-operations (like numpy)

# %% [markdown]
# Just like with numpy arrays, many operations are element-wise:

# %%
population / 100
# Out:
# Germany           0.813
# Belgium           0.113
# France            0.643
# United Kingdom    0.649
# Netherlands       0.169
# dtype: float64

# %%
countries['population'] / countries['area']
# Out:
# 0    0.000370
# 1    0.000096
# 2    0.000228
# 3    0.000407
# 4    0.000265
# dtype: float64

# %% [markdown]
# ### Alignment! (unlike numpy)
#
# Only, pay attention to **alignment**: operations between series will align on the index:

# %%
s1 = population[['Belgium', 'France']]
s2 = population[['France', 'Germany']]

# %%
s1
# Out:
# Belgium    11.3
# France     64.3
# dtype: float64

# %%
s2
# Out:
# France     64.3
# Germany    81.3
# dtype: float64

# %%
s1 + s2
# Out:
# Belgium      NaN
# France     128.6
# Germany      NaN
# dtype: float64

# %% [markdown]
# ### Reductions (like numpy)

# %% [markdown]
# The average population number:

# %%
population.mean()
# Out:
# 47.739999999999995

# %% [markdown]
# The minimum area:

# %%
countries['area'].min()
# Out:
# 30510

# %% [markdown]
# For dataframes, often only the numeric columns are included in the result:

# %%
countries.median()
# Out:
# population        64.3
# area          244820.0
# dtype: float64

# %% [markdown]
# ## Practice 2
#
# **Calculate the population numbers relative to Belgium**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
c = population['Belgium']*1000000
c
# Out:
# 11300000.0

# %% [markdown]
# **Calculate the population density for each country and add this as a new column to the dataframe.**

# %% [markdown]
# Full Name: Lê Thanh Phương Nam - ID: ITITUN19008

# %%
countries['density'] = countries['population']*1000000 / countries['area']
# Out:
#           country  population    area    capital     density
# 0         Belgium        11.3   30510   Brussels  370.370370
# 1          France        64.3  671308      Paris   95.783158
# 2         Germany        81.3  357050     Berlin  227.699202
# 3     Netherlands        16.9   41526  Amsterdam  406.973944
# 4  United Kingdom        64.9  244820     London  265.092721

# %%
countries
# Out:
#           country  population    area    capital     density
# 0         Belgium        11.3   30510   Brussels  370.370370
# 1          France        64.3  671308      Paris   95.783158
# 2         Germany        81.3  357050     Berlin  227.699202
# 3     Netherlands        16.9   41526  Amsterdam  406.973944
# 4  United Kingdom        64.9  244820     London  265.092721

# %% [markdown]
# ### Some other useful methods

# %% [markdown]
# Sorting the rows of the DataFrame according to the values in a column:

# %%
countries.sort_values('density', ascending=False)
# Out:
#           country  population    area    capital     density
# 3     Netherlands        16.9   41526  Amsterdam  406.973944
# 0         Belgium        11.3   30510   Brussels  370.370370
# 4  United Kingdom        64.9  244820     London  265.092721
# 2         Germany        81.3  357050     Berlin  227.699202
# 1          France        64.3  671308      Paris   95.783158

# %% [markdown]
# One useful method to use is the ``describe`` method, which computes summary statistics for each column:

# %%
countries.describe()
# Out:
#        population           area     density
# count    5.000000       5.000000    5.000000
# mean    47.740000  269042.800000  273.183879
# std     31.519645  264012.827994  123.440607
# min     11.300000   30510.000000   95.783158
# 25%     16.900000   41526.000000  227.699202
# 50%     64.300000  244820.000000  265.092721
# 75%     64.900000  357050.000000  370.370370
# max     81.300000  671308.000000  406.973944

# %% [markdown]
# The `plot` method can be used to quickly visualize the data in different ways:

# %%
countries.plot()

# %% [markdown]
# However, for this dataset, it does not say that much:

# %%
countries['population'].plot(kind='bar')

# %% [markdown]
# You can play with the `kind` keyword: 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'

# %% [markdown]
# ## Importing and exporting data

# %% [markdown]
# A wide range of input/output formats are natively supported by pandas:
#
# * CSV, text
# * SQL database
# * Excel
# * HDF5
# * json
# * html
# * pickle
# * ...

# %%
pd.read

# %%
states.to

# %% [markdown]
# ## Other features
#
# * Working with missing data (`.dropna()`, `pd.isnull()`)
# * Merging and joining (`concat`, `join`)
# * Grouping: `groupby` functionality
# * Reshaping (`stack`, `pivot`)
# * Time series manipulation (resampling, timezones, ..)
# * Easy plotting

# %% [markdown]
# There are many, many more interesting operations that can be done on Series and DataFrame objects, but rather than continue using this toy data, we'll instead move to a real-world example, and illustrate some of the advanced concepts along the way.
#
# See the next notebooks!

# %% [markdown]
# ## Acknowledgement
#
# > *© 2015, Stijn Van Hoey and Joris Van den Bossche  (<mailto:stijnvanhoey@gmail.com>, <mailto:jorisvandenbossche@gmail.com>). Licensed under [CC BY 4.0 Creative Commons](http://creativecommons.org/licenses/by/4.0/)*
#
# > This notebook is partly based on material of Jake Vanderplas (https://github.com/jakevdp/OsloWorkshop2014).
#
# ---
